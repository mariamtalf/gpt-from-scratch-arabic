# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/Colab Notebooks/GPT-from-Scratch/notebooks/"
os.chdir(PROJECT_DIR)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/GPT-from-Scratch/notebooks

# %%
import os
import matplotlib.pyplot as plt
from collections import Counter

# %%
file_path = "../data/pretrain/data.txt"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

print("First 500 characters:\n")
print(text[:500])
# Out:
# First 500 characters:
#
# موسوعة مصر القديمة (الجزء السادس)
#
# موسوعة مصر القديمة (الجزء السادس)
#
# عصر رعمسيس الثاني وقيام الإمبراطورية الثانية
#
# تأليف
# سليم حسن
#
# تمهيد
#
# كانت نهاية الأسرة الثامنة عشرة — وهي آخر مرحلة وصلنا إليها في الجزء السالف — فاتحة عصر جديد في تاريخ مصر وسياستها في الداخل وفي الخارج، وهو عصر قيام الإمبراطورية الثانية على يد سلسلة من الفراعنة الأماجد.
#
# فقد قضى «حور محب» على النظام الديني الذي اصطفاه «إخناتون»، وكان يُعد في جوهره وثبة قوية نحو عقيدة التوحيد الحقة، فرجعت البلاد ثانية إلى ديانتها التقليدية ال

# %%
lines = text.split("\n")
words = text.split()

print("Number of lines:", len(lines))
print("Number of words:", len(words))
print("Number of characters:", len(text))
# Out:
# Number of lines: 7803
# Number of words: 195743
# Number of characters: 1109540

# %%
word_counts = Counter(words)

print("Unique words:", len(word_counts))

print("\nMost common words:")
for word, count in word_counts.most_common(20):
    print(word, count)
# Out:
# Unique words: 38708
#
# Most common words:
# في 6781
# من 4451
# على 3617
# أن 2466
# التي 1687
# كان 1644
# هذا 1464
# الذي 1367
# وقد 1321
# إلى 1246
# قد 1240
# هذه 1033
# ما 933
# «رعمسيس 908
# كل 849
# كانت 777
# ذلك 726
# — 721
# )راجع: 711
# كما 680

# %%
lengths = [len(w) for w in words]

plt.hist(lengths, bins=10)
plt.title("Word Length Distribution")
plt.xlabel("Length")
plt.ylabel("Frequency")
plt.show()
